# %%
import pandas as pd

# %% [markdown]
# ## Create dataframe

# %%
reviews = pd.read_csv('reviews 2 reduced.csv')

# %%
listings = pd.read_csv('listings 2 reduced.csv')

# %% [markdown]
# ## Retrive rows

# %%
reviews.head()
# Out:
#    listing_id                  id        date  reviewer_id reviewer_name  \
# 0       13913  597622110054753727  2022-04-04      2941217         Kévin
# 1       13913  628812668788849576  2022-05-17     32486646        Saarah
# 2       13913  631032182017371215  2022-05-20    203803703        Mallin
# 3       13913  632423370762131190  2022-05-22    172968198           Ged
# 4       13913  646234379625287966  2022-06-10     27083732        Robert
#
#                                             comments
# 0           If the room is available, just take it !
# 1  Alina's flat is lovely and quirky, with art al...
# 2  This is the most cosy and beautifully-decorate...
# 3  Alina was very welcoming, friendly  and helpfu...
# 4  An arty flat, clean and comfortable big room, ...

# %%
listings.tail()
# Out:
#                        id    host_id  host_since  host_listings_count  \
# 87941  973781286754517228  498408783  2023-01-28                  2.0
# 87942  973801695874775338   36645347  2015-06-24                  1.0
# 87943  973811685656289740  340514057  2020-03-06                  1.0
# 87944  973882998775927897  439074505  2022-01-05               2538.0
# 87945  973895808066047620  475112423  2022-08-15                 37.0
#
#       host_identity_verified  calculated_host_listings_count  \
# 87941                      t                               2
# 87942                      t                               1
# 87943                      t                               1
# 87944                      t                             170
# 87945                      t                               6
#
#               property_type        room_type instant_bookable  minimum_nights  \
# 87941    Entire rental unit  Entire home/apt                f               2
# ...

# %% [markdown]
# ## Get list of columns and datatypes

# %%
listings.dtypes
# Out:
# id                                  int64
# host_id                             int64
# host_since                         object
# host_listings_count               float64
# host_identity_verified             object
# calculated_host_listings_count      int64
# property_type                      object
# room_type                          object
# instant_bookable                   object
# minimum_nights                      int64
# maximum_nights                      int64
# number_of_reviews                   int64
# reviews_per_month                 float64
# price                              object
# bedrooms                          float64
# beds                              float64
# host_is_superhost                  object
# neighbourhood_cleansed             object
# review_scores_rating              float64
# review_scores_accuracy            float64
# review_scores_cleanliness         float64
# review_scores_checkin             float64
# ...

# %% [markdown]
# ## Convert column datatype

# %%
listings['price']
# Out:
# 0         42.00
# 1        175.00
# 2         79.00
# 3        150.00
# 4         46.00
#           ...
# 87941    275.00
# 87942    145.00
# 87943    160.00
# 87944    680.00
# 87945    170.00
# Name: price, Length: 87946, dtype: object

# %%
listings['price'] = listings['price'].str.replace('$', '').str.replace(',', '')

# %%
listings['price'] = listings['price'].astype(float)

# %%
listings.dtypes
# Out:
# id                                  int64
# host_id                             int64
# host_since                         object
# host_listings_count               float64
# host_identity_verified             object
# calculated_host_listings_count      int64
# property_type                      object
# room_type                          object
# instant_bookable                   object
# minimum_nights                      int64
# maximum_nights                      int64
# number_of_reviews                   int64
# reviews_per_month                 float64
# price                             float64
# bedrooms                          float64
# beds                              float64
# host_is_superhost                  object
# neighbourhood_cleansed             object
# review_scores_rating              float64
# review_scores_accuracy            float64
# review_scores_cleanliness         float64
# review_scores_checkin             float64
# ...

# %% [markdown]
# ## Unique Values in a Column

# %%
listings.room_type.unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Hotel room', 'Shared room'],
#       dtype=object)

# %% [markdown]
# ## Filtering Columns

# %%
listings[['host_id', 'property_type', 'property_type', 'room_type', 'price']]
# Out:
#          host_id                property_type                property_type  \
# 0         498201  Private room in rental unit  Private room in rental unit
# 1         499704           Entire rental unit           Entire rental unit
# 2          54730  Private room in rental unit  Private room in rental unit
# 3          60302           Entire rental unit           Entire rental unit
# 4         497514        Private room in condo        Private room in condo
# ...          ...                          ...                          ...
# 87941  498408783           Entire rental unit           Entire rental unit
# 87942   36645347           Entire rental unit           Entire rental unit
# 87943  340514057         Private room in home         Private room in home
# 87944  439074505                  Entire home                  Entire home
# 87945  475112423           Entire rental unit           Entire rental unit
#
#              room_type  price
# 0         Private room   42.0
# ...

# %% [markdown]
# ## Filtering Rows

# %%
listings[(listings['room_type']=='Private room')]
# Out:
#                        id    host_id  host_since  host_listings_count  \
# 0                   92644     498201  2011-04-10                  1.0
# 2                   13913      54730  2009-11-16                  3.0
# 4                   93734     497514  2011-04-10                  1.0
# 9                   25123     103583  2010-04-05                  3.0
# 11                  96052     448154  2011-03-17                  2.0
# ...                   ...        ...         ...                  ...
# 87927  973375658553846760  109385731  2017-01-01                 17.0
# 87928  973436004574514476  534665388  2023-08-30                  6.0
# 87929  973448499788404098  514093963  2023-05-10                  1.0
# 87937  973718990194023243  107003671  2016-12-12                  1.0
# 87943  973811685656289740  340514057  2020-03-06                  1.0
#
#       host_identity_verified  calculated_host_listings_count  \
# 0                          t                               1
# ...

# %% [markdown]
# ## Indexing with iloc

# %%
listings.iloc[-1]    ## grab last row from the dataframe
# Out:
# id                                                               973895808066047620
# host_id                                                                   475112423
# host_since                                                               2022-08-15
# host_listings_count                                                            37.0
# host_identity_verified                                                            t
# calculated_host_listings_count                                                    6
# property_type                                                    Entire rental unit
# room_type                                                           Entire home/apt
# instant_bookable                                                                  f
# minimum_nights                                                                    1
# maximum_nights                                                                  365
# ...

# %%
listings.iloc[999, 1]  ##first is row, then column
# Out:
# 4401190

# %%
reviews.iloc[100:200]    ##get subset of the data
# Out:
#      listing_id                  id        date  reviewer_id reviewer_name  \
# 100      264789  604161148194498169  2022-04-13     71869511        Lesley
# 101      264789  617951332558803251  2022-05-02     30087141        Samuel
# 102      264789  643285433336251885  2022-06-06     13310518        Eileen
# 103      264789  663640383803094368  2022-07-04    418185119           Tom
# 104      264789  681677861979716229  2022-07-29    449857368    Desloovere
# ..          ...                 ...         ...          ...           ...
# 195      268398  688247625933241599  2022-08-07    330623213       Maureen
# 196      268398  691861569431978214  2022-08-12     63870694      Veronica
# 197      268398  701334225177058053  2022-08-25    192339945           Min
# 198      268398  702725237709391014  2022-08-27     14953626         Allie
# 199      268398  704129758685213765  2022-08-29     62308557          Théo
#
#                                               comments
# ...

# %% [markdown]
# ## Count Null value in dataframe

# %%
listings.isnull().sum()
# Out:
# id                                    0
# host_id                               0
# host_since                            5
# host_listings_count                   5
# host_identity_verified                5
# calculated_host_listings_count        0
# property_type                         0
# room_type                             0
# instant_bookable                      0
# minimum_nights                        0
# maximum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 22158
# price                                 0
# bedrooms                          32774
# beds                               1134
# host_is_superhost                   932
# neighbourhood_cleansed                0
# review_scores_rating              22158
# review_scores_accuracy            23093
# review_scores_cleanliness         23081
# review_scores_checkin             23125
# review_scores_communication       23095
# ...

# %% [markdown]
# ## Merging Dataframes

# %%
listings_reviews_merge = pd.merge(listings, reviews, how="outer", left_on='id', right_on='listing_id')

# %%
listings_reviews_merge.head()
# Out:
#       id_x   host_id  host_since  host_listings_count host_identity_verified  \
# 0  92644.0  498201.0  2011-04-10                  1.0                      t
# 1  92644.0  498201.0  2011-04-10                  1.0                      t
# 2  92644.0  498201.0  2011-04-10                  1.0                      t
# 3  92644.0  498201.0  2011-04-10                  1.0                      t
# 4  92644.0  498201.0  2011-04-10                  1.0                      t
#
#    calculated_host_listings_count                property_type     room_type  \
# 0                             1.0  Private room in rental unit  Private room
# 1                             1.0  Private room in rental unit  Private room
# 2                             1.0  Private room in rental unit  Private room
# 3                             1.0  Private room in rental unit  Private room
# 4                             1.0  Private room in rental unit  Private room
#
# ...

# %%
listings_reviews_merge.isnull().sum()
# Out:
# id_x                                   7
# host_id                                7
# host_since                            12
# host_listings_count                   12
# host_identity_verified                12
# calculated_host_listings_count         7
# property_type                          7
# room_type                              7
# instant_bookable                       7
# minimum_nights                         7
# maximum_nights                         7
# number_of_reviews                      7
# reviews_per_month                  22165
# price                                  7
# bedrooms                          350524
# beds                               11978
# host_is_superhost                  11507
# neighbourhood_cleansed                 7
# review_scores_rating               22165
# review_scores_accuracy             23100
# review_scores_cleanliness          23088
# review_scores_checkin              23132
# review_scores_communication        23102
# ...
